# %% [markdown]
# ## **"Automated State & Country Identification and Address Completion Using LangChain and OpenAI"**

# %% [markdown]
# **Objective:**
# * This project aims to automatically identify and fill missing State and Country fields in a dataset using LangChain and OpenAI's GPT model. By leveraging AI, the system extracts accurate state names based on existing Pincode, Location, and Address data, ensuring a more complete and structured dataset for analysis.

# %% [markdown]
# **Step-1 : Load the necessary libraries**

# %%
import os 
import pandas as pd 
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.schema.messages import SystemMessage, HumanMessage

# %% [markdown]
# **Step-2 : Enter your API key**

# %%
os.environ["OPENAI_API_KEY"] = "Add_your _API_key"
llm = ChatOpenAI(model_name = "gpt-3.5-turbo", temperature = 0.3)
# Out:
# C:\Users\gkris\AppData\Local\Temp\ipykernel_12504\14006444.py:2: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model_name = "gpt-3.5-turbo", temperature = 0.3)

# %% [markdown]
# **Step-3 : Load the updated csv file**

# %%
file_path = "E:\\Projects\\updated_pincodes1.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#   Company Name       Street Name                     Place  \
# 0        Wipro    Dodda Kannelli             Sarjapur Road
# 1        Wipro            No. 72   Keonics Electronic City
# 2        Wipro  Survey No. 203/1         Manikonda Village
# 3        Wipro        Plot No. 2                      MIDC
# 4          TCS               185               Lloyds Road
#
#                                       Location  Pincode  \
# 0                                    Bangalore   560035
# 1                                    Bangalore   560100
# 2                                    Hyderabad   500089
# 3   Rajiv Gandhi Infotech Park ,Hinjewadi,pune   411057
# 4                          Gopalapuram,Chennai   600086
#
#                                              Address  \
# 0          Dodda Kannelli,  Sarjapur Road, Bangalore
# 1        No. 72,  Keonics Electronic City, Bangalore
# 2    Survey No. 203/1,  Manikonda Village, Hyderabad
# 3  Plot No. 2,  MIDC,  Rajiv Gandhi Infotech Park...
# 4            185,  Lloyds Road,  Gopalapuram,Chennai
#
#                                                 text
# 0          Dodda Kannelli,  Sarjapur Road, Bangalore
# 1        No. 72,  Keonics Electronic City, Bangalore
# 2    Survey No. 203/1,  Manikonda Village, Hyderabad
# 3  Plot No. 2,  MIDC,  Rajiv Gandhi Infotech Park...
# 4            185,  Lloyds Road,  Gopalapuram,Chennai

# %% [markdown]
# **Step-4 : Create an empty column in the dataset**

# %%
if "State"  not in df.columns:
    df["State"] = None

# %%
df = df.drop(columns = ["text"], axis = 1)

# %%
def get_state(pincode, location, address):
    """Use OpenAI to predict the state based on pincode, location and place."""
    messages = [
        SystemMessage(content = "You are an AI assistant that provides the correct Indian State Name based on the Pincode, Location and Place."),
        HumanMessage(content = f"Which state does the following belong to \nPincode : {pincode}\nLocation : {location}\nPlace : {address}\n return only the state name.")
    ]
    response = llm(messages)
    return response.content.strip()

# %% [markdown]
# **Step-5 : Fill missing values in the "State" column**

# %%
df["State"] = df.apply(lambda row : get_state(row["Pincode"], row["Location"], row["Place"]) if pd.isna(row["State"])else row["State"], axis = 1)
# Out:
# C:\Users\gkris\AppData\Local\Temp\ipykernel_12504\557638415.py:7: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm(messages)

# %%
if "Country" not in df.columns:
    df["Country"] = None

# %%
def get_country(state):
    """Use OpenAI to predict the country based on state"""
    messages = [
        SystemMessage(content = "You are an AI assistant that provides the correct Country Name based on the State."),
        HumanMessage(content = f"Which country does the following belong to \nState : {state} return only country name.")
    ]
    response = llm(messages)
    return response.content.strip()

# %%
df["Country"] = df.apply(lambda row : get_country(row["State"]) if pd.isna(row["Country"]) else row["Country"], axis = 1)

# %%
df.head(21)
# Out:
#    Company Name                    Street Name                        Place  \
# 0         Wipro                 Dodda Kannelli                Sarjapur Road
# 1         Wipro                         No. 72      Keonics Electronic City
# 2         Wipro               Survey No. 203/1            Manikonda Village
# 3         Wipro                     Plot No. 2                         MIDC
# 4           TCS                            185                  Lloyds Road
# 5           TCS                          No. 1        Software Units Layout
# 6           TCS                    IT/ITES SEZ                     Rajarhat
# 7           TCS                        No. 769                   Anna Salai
# 8           TCS                    Deccan Park                   Plot No. 1
# 9           TCS                   Think Campus     Electronic City Phase II
# 10          TCS                     Plot No. 1                 Block No. EP
# 11          TCS                    Yantra Park                        Thane
# 12      Infosys                 Survey No. 210            Manikonda Village
# 13      Infosys                Plot No. IIIG/2                      AA-IIIG
# 14      Infosys           Floor 9 to12 Tower B                  Ace Capitol
# 15      Infosys                            138       Old Mahabalipuram Road
# 16      Infosys                      Plot No.1   Rajiv Gandhi Infotech Park
# 17    Cognizant                           H-04            Hitec City Layout
# 18    Cognizant                    New No. 165                  Old No. 110
# 19    Cognizant                    Plot No. 26   Rajiv Gandhi Infotech Park
# 20    Cognizant  Manyata Embassy Business Park              Outer Ring Road
#
#                                              Location  Pincode  \
# 0                                           Bangalore   560035
# 1                                           Bangalore   560100
# 2                                           Hyderabad   500089
# 3          Rajiv Gandhi Infotech Park ,Hinjewadi,pune   411057
# 4                                 Gopalapuram,Chennai   600086
# 5                                  Madhapur,Hyderabad   500081
# 6                                    New Town,Kolkata   700160
# 7                                             Chennai   600002
# 8            Software units layout,Madhapur,Hyderabad   500081
# 9                                           Bangalore   560100
# 10    Secotr V,Salt Lake Electronics Complex,kolkatta   700091
# 11                                             Mumbai   400601
# 12                             ,Lingampally,Hyderabad   500019
# 13    St No.3333,4 New Town- Action area- III,Kolkata   700135
# 14         Sector 132, Greater Noida Expressway,Noida   201304
# 15                             Sholinganallur,Chennai   600119
# 16                            Hinjawadi, Phase-I,pune   411057
# 17                  Survey No. 64, Madhapur,hyderabad   500081
# 18    Menon Eternity Building,St. Mary's Road,Alwa...   600018
# 19                               MIDC, Hinjewadi,pune   411057
# 20                                 Nagavara,Bangalore   560045
#
#                                               Address  \
# 0           Dodda Kannelli,  Sarjapur Road, Bangalore
# 1         No. 72,  Keonics Electronic City, Bangalore
# 2     Survey No. 203/1,  Manikonda Village, Hyderabad
# 3   Plot No. 2,  MIDC,  Rajiv Gandhi Infotech Park...
# 4             185,  Lloyds Road,  Gopalapuram,Chennai
# 5   No. 1,  Software Units Layout, Madhapur,Hyderabad
# 6            IT/ITES SEZ,  Rajarhat, New Town,Kolkata
# 7                       No. 769,  Anna Salai, Chennai
# 8   Deccan Park,  Plot No. 1,  Software units layo...
# 9   Think Campus,  Electronic City Phase II, Banga...
# 10  Plot No. 1,  Block No. EP,  Secotr V,Salt Lake...
# 11                        Yantra Park,  Thane, Mumbai
# 12  Survey No. 210,  Manikonda Village, ,Lingampal...
# 13  Plot No. IIIG/2,  AA-IIIG,  St No.3333,4 New T...
# 14  Floor 9 to12 Tower B,  Ace Capitol,  Sector 13...
# 15  138,  Old Mahabalipuram Road,  Sholinganallur,...
# 16  Plot No.1,  Rajiv Gandhi Infotech Park,  Hinja...
# 17  H-04,  Hitec City Layout,  Survey No. 64, Madh...
# 18  New No. 165,  Old No. 110,   Menon Eternity Bu...
# 19  Plot No. 26,  Rajiv Gandhi Infotech Park,  MID...
# 20  Manyata Embassy Business Park,  Outer Ring Roa...
#
#                                                 State Country
# 0                                           Karnataka   India
# 1                                           Karnataka   India
# 2                                           Telangana   India
# 3   The Pincode 411057, Location Rajiv Gandhi Info...   India
# 4                                          Tamil Nadu   India
# 5                                           Telangana   India
# 6                                         West Bengal   India
# 7                                          Tamil Nadu   India
# 8                                           Telangana   India
# 9                                           Karnataka   India
# 10  The Pincode 700091, Location Secotr V, Salt La...   India
# 11  The Pincode 400601 belongs to the state of Mah...   India
# 12                                          Telangana   India
# 13  The Pincode 700135 corresponds to the state of...   India
# 14                                      Uttar Pradesh   India
# 15  The given details correspond to the state of T...   India
# 16  The Pincode 411057, Location Hinjawadi, Phase-...   India
# 17                                          Telangana   India
# 18                                         Tamil Nadu   India
# 19  The Pincode 411057, Location MIDC, Hinjewadi, ...   India
# 20                                          Karnataka   India

# %% [markdown]
# **Step-6 : Download the updated file**

# %% [markdown]
# * If you want to download the csv execute the below code.

# %%
# df.to_csv("updated_states.csv", index = False)

# %% [markdown]
# **Conclusion:**
# * This project successfully automates the process of identifying missing state and country names and completing address details using LangChain and OpenAI's GPT model. By leveraging AI, we ensure accurate and consistent data enrichment based on existing Pincode, Location, and Address information. This approach enhances data quality, minimizes manual effort, and provides a scalable solution for large datasets, making it valuable for businesses and applications that rely on precise geographical information.
